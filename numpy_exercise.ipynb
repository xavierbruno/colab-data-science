# %% [markdown]
# <a href="https://colab.research.google.com/github/xavierbruno/python-data-science/blob/master/numpy_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/allanspadini/numpy/dados/citrus.csv'
dado = np.loadtxt(url, delimiter=',', skiprows=1, usecols=np.arange(1,6,1))

# %%
dado
# Out:
# array([[  2.96,  86.76, 172.  ,  85.  ,   2.  ],
#        [  3.91,  88.05, 166.  ,  78.  ,   3.  ],
#        [  4.42,  95.17, 156.  ,  81.  ,   2.  ],
#        ...,
#        [ 15.59, 256.5 , 168.  ,  82.  ,  20.  ],
#        [ 15.92, 260.14, 142.  ,  72.  ,  11.  ],
#        [ 16.45, 261.51, 152.  ,  74.  ,   2.  ]])

# %%
urlApples = 'https://raw.githubusercontent.com/xavierbruno/python-data-science/refs/heads/master/apples_ts.csv'
dadoApples = np.loadtxt(urlApples, delimiter=',', usecols=np.arange(1,88,1))

# %%
dados_laranja = dado[:5000]  # Linhas 0 a 4999
diametro_laranja = dados_laranja[:, 0]
peso_laranja = dados_laranja[:, 1]

dados_toranja = dado[5000:]  # Linhas 5000 até o final
diametro_toranja = dados_toranja[:, 0]
peso_toranja = dados_toranja[:, 1]

# %%
Y1 = peso_laranja
Y2 = peso_toranja
X1 = diametro_laranja
X2 = diametro_toranja
n1 = np.size(peso_laranja)
n2 = np.size(peso_toranja)

print("Número de amostras de toranja:", n2)
print("Valores de X2 (diâmetro toranja):", X2)
print("Valores de Y2 (peso toranja):", Y2)
# Out:
# Número de amostras de toranja: 5000
# Valores de X2 (diâmetro toranja): [ 7.63  7.69  7.72 ... 15.59 15.92 16.45]
# Valores de Y2 (peso toranja): [126.79 133.98 135.56 ... 256.5  260.14 261.51]

# %%
a1 = (n1*np.sum(X1*Y1) - np.sum(X1)*np.sum(Y1))/(n1*np.sum(X1**2)-(np.sum(X1)**2))
a2 = (n2*np.sum(X2*Y2) - np.sum(X2)*np.sum(Y2))/(n2*np.sum(X2**2)-(np.sum(X2)**2))

# %%
b1 = np.mean(Y2) - a1*np.mean(X1)
b2 = np.mean(Y2) - a2*np.mean(X2)

# %%
y1 = a1*X1+b1
y2 = a2*X2+b2

# %%
plt.plot(diametro_laranja,peso_laranja)
plt.plot(X1,y1)
plt.plot(diametro_toranja, peso_toranja)
plt.plot(X2,y2)

plt.legend(['Peso Laranja', 'Crescimento esperado Laranja', 'Peso Toranja', 'Crescimento esperado Toranja'])
